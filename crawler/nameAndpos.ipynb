# %%
import scrapy
from scrapy import *
from scrapy.crawler import CrawlerProcess
import pandas as pd 
from scrapy.crawler import CrawlerRunner
import numpy as np
import scrapy.crawler as crawler
from twisted.internet import reactor
import json
from scrapy import Request

# %%
class test1(scrapy.Spider):
    name = 'test1'
    header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36'}
    
    
    def start_requests(self):
        site = ["https://ulist.moe.gov.tw/Query/Area/N"]
        
        
    
        for i in site:
            yield scrapy.Request(url =i,meta = {'index':1})
   
    
    def parse(self,response):
        name = response.xpath('//*[@id="grid"]/tbody/tr/td/a[not(contains(text(),"網站連結"))]/text()').getall()
     
        pos= response.xpath('//*[@id="grid"]/tbody/tr/td[not(contains(text(),"\r\n")orcontains(text(),"公立")orcontains(text(),"一般大學"))]/text()').getall()
        #or(contains(text(),"技專校院"))or(contains(text(),"私立")]/text()
        #title = response.xpath('/html/body/main/div/section/ul/li/a/text()').getall()
        #ids  = response.xpath('/html/body/main/div/section/ul/li/a[not(contains(@href,"special"))]/@href').getall()
        print("hi")
        
        print(name)
        print(pos)

# %%
process = CrawlerProcess()
process.crawl(test1)
process.start()
# Out:
# 2020-06-04 15:36:33 [scrapy.utils.log] INFO: Scrapy 2.1.0 started (bot: scrapybot)
# 2020-06-04 15:36:33 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug 13 2019, 20:35:49) - [GCC 7.3.0], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Linux-5.3.0-53-generic-x86_64-with-debian-buster-sid
# 2020-06-04 15:36:33 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2020-06-04 15:36:33 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-06-04 15:36:33 [scrapy.extensions.telnet] INFO: Telnet Password: 2872e5a7f364777d
# 2020-06-04 15:36:33 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %% [raw]
# from lxml import etree
# doc = '''<input name="__RequestVerificationToken" type="hidden" value="_3SyDJN_my-u6GY_3Akz26D7TXzp-fGUTRPq2OY5z4TH3F0q6CUypCF4UoTD7FMfzBc_tnrE5bIYM6xGw49zZd6XxwrYp-7N1atYrEXYDP81" />
# <table id="grid" class="dataResult">
#     <thead>
#         <tr>
#             <th style="text-align:center" class="kiketable-th">公私立</th>
#             <th style="text-align:center" class="kiketable-th">體制</th>
#             <th style="text-align:center" class="kiketable-th">學校名稱</th>
#             <th style="text-align:center" class="kiketable-th">學校地址</th>
#             <th style="text-align:center" class="kiketable-th">學校網址</th>
#         </tr>
#     </thead>
#     <tbody>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE1321" target="_blank">國立政治大學</a>
#                         </td>
#                         <td style="text-align:left">臺北市文山區指南路2段64號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.nccu.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE1E8D" target="_blank">國立清華大學</a>
#                         </td>
#                         <td style="text-align:left">新竹市光復路2段101號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.nthu.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE2C02" target="_blank">國立臺灣大學</a>
#                         </td>
#                         <td style="text-align:left">臺北市大安區羅斯福路4段1號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.ntu.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE4A35" target="_blank">國立臺灣師範大學</a>
#                         </td>
#                         <td style="text-align:left">臺北市大安區和平東路1段162號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.ntnu.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE7512" target="_blank">國立交通大學</a>
#                         </td>
#                         <td style="text-align:left">新竹市大學路1001號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.nctu.edu.tw/" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE7F19" target="_blank">國立中央大學</a>
#                         </td>
#                         <td style="text-align:left">桃園市中壢區中大路300號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.ncu.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">公立</td>
#                         <td style="text-align:left">一般大學</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FE907C" target="_blank">國立臺灣海洋大學</a>
#                         </td>
#                         <td style="text-align:left">基隆市北寧路2號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.
</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.tumt.edu.tw/bin/home.php" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=00001712F46C" target="_blank">亞東技術學院</a>
#                         </td>
#                         <td style="text-align:left">新北市板橋區四川路二段58號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.oit.edu.tw/bin/home.php" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=00001712F741" target="_blank">南亞科技學校財團法人南亞技術學院</a>
#                         </td>
#                         <td style="text-align:left">桃園市中壢區中山東路三段414號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.nanya.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=00001712FB11" target="_blank">黎明技術學院</a>
#                         </td>
#                         <td style="text-align:left">新北市泰山區泰林路三段22號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://WWW.LIT.EDU.TW/" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=00001712FEB6" target="_blank">經國管理暨健康學院</a>
#                         </td>
#                         <td style="text-align:left">基隆市中山區復興路336號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://WWW.CKU.EDU.TW" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=0000171303AD" target="_blank">馬偕學校財團法人馬偕醫護管理專科學校</a>
#                         </td>
#                         <td style="text-align:left">新北市三芝區中正路三段42號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://WWW.MKC.EDU.TW/" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000017130676" target="_blank">仁德醫護管理專科學校</a>
#                         </td>
#                         <td style="text-align:left">苗栗縣後龍鎮溪洲里7鄰砂崙湖79-9號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.jente.edu.tw/" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000017131248" target="_blank">耕莘健康管理專科學校</a>
#                         </td>
#                         <td style="text-align:left">新北市新店區民族路112號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.ctcn.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">技專校院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000017131C1E" target="_blank">新生醫護管理專科學校</a>
#                         </td>
#                         <td style="text-align:left">桃園市龍潭區中豐路高平段418號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://WWW.HSC.EDU.TW" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">宗教研修學院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FFF4A3" target="_blank">學校財團法人中華浸信會基督教台灣浸會神學院</a>
#                         </td>
#                         <td style="text-align:left">臺北市吳興街394巷1號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.tbts.edu.tw/" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">宗教研修學院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FFF4EA" target="_blank">臺北基督學院</a>
#                         </td>
#                         <td style="text-align:left">新北市淡水區自強路51號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.cct.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#                     <tr>
#                             <td style="text-align:left">私立</td>
#                         <td style="text-align:left">宗教研修學院</td>
#                         <td style="text-align:left">
#                             <a href="/Browse/UniversityDetail?UniversityKey=000016FFF605" target="_blank">台神學校財團法人台灣神學研究學院</a>
#                         </td>
#                         <td style="text-align:left">台北市士林區仰德大道二段二巷20號</td>
#                         <td style="text-align:left"><a class="Normallink" href="http://www.tgst.edu.tw" target="_blank">網站連結</a></td>
#                     </tr>
#
#     </tbody>
# </table>'''

# %%
tree = etree.HTML(doc)

name = tree.xpath('//*[@id="grid"]/tbody/tr/td/a[not(contains(text(),"網站連結"))]/text()')
pos = tree.xpath('//*[@id="grid"]/tbody/tr/td[not(contains(text(),"\r\n")orcontains(text(),"公立")orcontains(text(),"一般大學")orcontains(text(),"私立")orcontains(text(),"技專校院")orcontains(text(),"\n")orcontains(text(),"空中大學")orcontains(text(),"宗教研修學院"))]/text()')

# %%
len(name)
# Out:
# 74

# %%
len(pos)
# Out:
# 74

# %%
temp = str()
temp+="name,pos\n"
for (i,j) in zip(name,pos):
    temp+=i+','+j+'\n'
with open("namePos.csv",'w')as f :
    f.write(temp)

# %%
import pandas as pd

# %%
df = pd.read_csv("namePos.csv")

# %%
df.to_csv("tet",index=False)
